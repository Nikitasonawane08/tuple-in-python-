# %% [markdown]
# # what is tuple in python?

# %% [markdown]
# # A tuple in Python is an ordered, immutable collection of elements used to store multiple values in a single variable.

# %%
tup1=()
print(type(tup1))
# Out:
# <class 'tuple'>

# %%
tup2=(10,30,60)

# %%
tup2[2]
# Out:
# 60

# %%
tup2
len(tup2)
# Out:
# 3

# %%
tup2.index(10)
# Out:
# 0

# %%
tup2
# Out:
# (10, 30, 60)

# %%
tup2=(10,30,60)

tup2[1]
# Out:
# 30

# %%
tup3=('data',20,[30,100],[190,29],['nikita','sakshi'],(10,2,3))

# %%
#update value in data
tup3[2][0]=58
tup3
# Out:
# ('data', 20, [58, 100], [190, 29], ['nikita', 'sakshi'], (10, 2, 3))

# %%
tup3=('data',20,[30,100],[190,29],['nikita','sakshi'],(10,2,3))

tup3[5][2]
# Out:
# 3

# %%
t1=('mango','apple','cherry')
t2=('banana','orange','grapes')
t1+t2
# Out:
# ('mango', 'apple', 'cherry', 'banana', 'orange', 'grapes')

# %%
t1=('mango','apple','cherry')
t1*2
# Out:
# ('mango', 'apple', 'cherry', 'mango', 'apple', 'cherry')

# %%
 #adding two tuple 
t1=('mango','apple','cherry')
t2=('banana','orange','grapes')

t1*2+t2*2
# Out:
# ('mango',
#  'apple',
#  'cherry',
#  'mango',
#  'apple',
#  'cherry',
#  'banana',
#  'orange',
#  'grapes',
#  'banana',
#  'orange',
#  'grapes')

# %% [markdown]
# # Practice question of tuples

# %%
#Create a tuple with 3 elements.
t1=('nikita',10,True,20.5)
t1
# Out:
# ('nikita', 10, True, 20.5)

# %%
#Access the second element of a tuple.
t1[1]
# Out:
# 10

# %%
#Find the length of a tuple.
len(t1)
# Out:
# 4

# %%
#Check if an element exists in tuple. first method
20.5 in t1
# Out:
# True

# %%
if 20.5  in t1:
    print("exists in tuple ")
else:
    print("not in tuple")
# Out:
# exists in tuple
